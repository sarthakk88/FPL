# %%
import fpl
import fbref
from datetime import datetime
import pandas as pd
import requests
import json
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#url 
# Make sure to keep the trailing “/” in the url!
#url = 'https://fantasy.premierleague.com/api/bootstrap-static/'
#response = fpl.get(url)

# %%
import requests
from bs4 import BeautifulSoup
from bs4 import Comment
import time
import csv

# %%
players_stats = pd.DataFrame(fbref.get_epl_players())

# %%
players_stats.head()
# Out:
#              player position            team     age birth_year games  \
# 0  Brenden Aaronson    MF,FW  [Leeds United]  22-188       2000    32
# 1         Che Adams       FW   [Southampton]  26-289       1996    26
# 2       Tyler Adams       MF  [Leeds United]  24-073       1999    24
# 3  Tosin Adarabioyo       DF        [Fulham]  25-216       1997    19
# 4      Nayef Aguerd       DF      [West Ham]  27-029       1996    14
#
#   games_starts minutes minutes_90s goals assists goals_assists goals_pens  \
# 0           28    2296        25.5     1       3             4          1
# 1           22    1903        21.1     5       3             8          5
# 2           24    2156        24.0     0       0             0          0
# 3           17    1545        17.2     1       0             1          1
# 4           13    1235        13.7     1       0             1          1
#
#   pens_made pens_att cards_yellow cards_red   xg npxg xg_assist  \
# 0         0        0            2         0  3.7  3.7       4.2
# 1         0        0            1         0  5.9  5.9       2.8
# 2         0        0            6         1  0.1  0.1       1.4
# 3         0        0            3         0  0.4  0.4       0.2
# 4         0        0            4         0  1.4  1.4       0.4
#
#   npxg_xg_assist progressive_carries progressive_passes  \
# 0            7.9                  43                 84
# 1            8.7                  14                 32
# 2            1.5                  19                136
# 3            0.6                  15                 71
# 4            1.8                   2                 18
#
#   progressive_passes_received goals_per90 assists_per90 goals_assists_per90  \
# 0                         147        0.04          0.12                0.16
# 1                         104        0.24          0.14                0.38
# 2                          20        0.00          0.00                0.00
# 3                           3        0.06          0.00                0.06
# 4                           4        0.07          0.00                0.07
#
#   goals_pens_per90 goals_assists_pens_per90 xg_per90 xg_assist_per90  \
# 0             0.04                     0.16     0.14            0.17
# 1             0.24                     0.38     0.28            0.13
# 2             0.00                     0.00     0.00            0.06
# 3             0.06                     0.06     0.02            0.01
# 4             0.07                     0.07     0.10            0.03
#
#   xg_xg_assist_per90 npxg_per90 npxg_xg_assist_per90
# 0               0.31       0.14                 0.31
# 1               0.41       0.28                 0.41
# 2               0.06       0.00                 0.06
# 3               0.03       0.02                 0.03
# 4               0.13       0.10                 0.13
