# %%
import understat
import requests
import json
from bs4 import BeautifulSoup
import re
import codecs
import pandas as pd
import os
import csv

# %%
team_frame,player_frame = understat.parse_epl_data()
# Out:
# c:\Users\hp\Desktop\Football\Code\fpl\understat.py:68: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   team = pd.DataFrame(teamData[t]["history"][-5:]).sum().drop("date")
# c:\Users\hp\Desktop\Football\Code\fpl\understat.py:68: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   team = pd.DataFrame(teamData[t]["history"][-5:]).sum().drop("date")
# ...

# %%
player_frame
# Out:
#         id              Player  goals  shots        xG        xA  assists  \
# 0     8260      Erling Haaland    6.0   19.0  5.225899  0.571936      3.0
# 1      647          Harry Kane    3.0   19.0  2.735150  1.616517      1.0
# 2      998          Ivan Toney    2.0   17.0  3.099559  0.892745      0.0
# 3      556     Marcus Rashford    2.0   16.0  3.131350  0.691572      2.0
# 4     1250       Mohamed Salah    4.0   19.0  3.919343  0.546795      0.0
# ..     ...                 ...    ...    ...       ...       ...      ...
# 535  11366          Jhon Durán    0.0    4.0  0.643946  0.000000      0.0
# 536  11367  Victor Kristiansen    0.0    2.0  0.032757  0.370665      1.0
# 537  11378      Máximo Perrone    0.0    0.0  0.000000  0.000000      0.0
# 538  11385         Yasin Ayari    0.0    1.0  0.012823  0.128754      0.0
# 539  11486      Illia Zabarnyi    0.0    0.0  0.000000  0.000000      0.0
#
#      key_passes  npg      npxG   xGChain  xGBuildup
# ...
