# %%
import fpl
import fbref
from datetime import datetime
import pandas as pd
import requests
import json
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#url 
# Make sure to keep the trailing “/” in the url!
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'
response = fpl.get(url)

# %%
goalies,defenders,midfielders,attackers = fpl.team_stats(response)

midfielders_stats = fpl.midfielders_stats(response,midfielders)
attackers_stats = fpl.attackers_stats(response,attackers)
defenders_stats = fpl.defenders_stats(response,defenders)
goalies_stats = fpl.goalies_stats(response,goalies)
# Out:
# c:\Users\hp\Desktop\Football\Code\fpl\fpl.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   players_data = a_players.append(h_players)

# %%
overall_goalies,overall_defenders,overall_midfielders,overall_attackers = fpl.overall_player_stats(response)

overall_midfielders_stats = fpl.midfielders_stats(response,overall_midfielders)
overall_attackers_stats = fpl.attackers_stats(response,overall_attackers)
overall_defenders_stats = fpl.defenders_stats(response,overall_defenders)
overall_goalies_stats = fpl.goalies_stats(response,overall_goalies)
# Out:
# c:\Users\hp\Desktop\Football\Code\fpl\fpl.py:537: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   players_data = a_players.append(h_players)

# %%
overall_midfielders_stats.assign(f = overall_midfielders_stats["total_points"]+overall_midfielders_stats["xPoints"]+overall_midfielders_stats["total_points_Home/Away"]+overall_midfielders_stats["xPoints_Home/Away"]).sort_values('f',ascending=False).drop('f', axis=1).head(30).drop_duplicates()
# Out:
#            first_name               second_name   id  minutes    xG    xA  \
# 109             Kevin                 De Bruyne  301      384  1.59  1.79
# 99            Mohamed                     Salah  283      375  3.30  0.72
# 98            Mohamed                     Salah  283      375  3.30  0.72
# 23              Kevin                 De Bruyne  301      384  1.59  1.79
# 116            Marcus                  Rashford  335      440  1.98  0.30
# 60            Gabriel          Martinelli Silva   19      407  0.89  1.98
# 110             Riyad                    Mahrez  303      379  1.75  0.46
# 126  Joelinton Cássio        Apolinário de Lira  371      439  3.07  0.13
# 25               Jack                  Grealish  305      427  1.04  1.35
# 111              Jack                  Grealish  305      427  1.04  1.35
# 30             Marcus                  Rashford  335      440  1.98  0.30
# 59             Bukayo                      Saka   13      379  1.41  0.88
# ...

# %%
overall_attackers_stats.assign(f = overall_attackers_stats["total_points"]+overall_attackers_stats["xPoints"]+overall_attackers_stats["total_points_Home/Away"]+overall_attackers_stats["xPoints_Home/Away"]).sort_values('f',ascending=False).drop('f', axis=1).head(30)
# Out:
#            first_name        second_name   id  minutes    xG    xA  \
# 36             Erling            Haaland  318      383  5.30  0.27
# 4              Erling            Haaland  318      383  5.30  0.27
# 0               Ollie            Watkins   40      450  2.76  0.32
# 19            Gabriel  Fernando de Jesus   28      374  4.99  0.15
# 11              Harry               Kane  427      450  2.78  0.81
# 41          Alexander               Isak  594      346  1.33  0.36
# 33              Diogo  Teixeira da Silva  288      369  2.71  0.56
# 32              Diogo  Teixeira da Silva  288      369  2.71  0.56
# 21               Ivan              Toney   80      442  3.28  0.44
# 22              Bryan             Mbeumo   95      347  0.90  0.81
# 18              Eddie            Nketiah   11      450  3.56  0.40
# 20            Dominic            Solanke   66      447  2.35  0.45
# 1                 Kai            Havertz  145      420  3.80  0.41
# ...

# %%
overall_defenders_stats.sort_values('xGC',ascending=True)
# Out:
#        first_name            second_name   id  minutes    xG    xA   xGC  \
# 22           John                 Stones  302      368  0.18  0.08  1.41
# 109          John                 Stones  302      368  0.18  0.08  1.41
# 23         Nathan                    Aké  308      429  0.10  0.38  2.44
# 110        Nathan                    Aké  308      429  0.10  0.38  2.44
# 61           Hugo            Bueno López  558      277  0.00  0.23  2.60
# 90        Joachim               Andersen  165      405  0.16  0.06  2.69
# 88           Joel                   Ward  156      401  0.07  0.18  3.29
# 113        Manuel                 Akanji  610      405  0.02  0.18  3.32
# 26         Manuel                 Akanji  610      405  0.02  0.18  3.32
# 112         Rúben        Gato Alves Dias  312      450  0.16  0.07  3.55
# 25          Rúben        Gato Alves Dias  312      450  0.16  0.07  3.55
# 3          Ashley                  Young  538      413  0.11  0.18  3.56
# ...

# %%
overall_defenders_stats.assign(f = overall_defenders_stats["total_points"]+overall_defenders_stats["xPoints"]+overall_defenders_stats["total_points_Home/Away"]+overall_defenders_stats["xPoints_Home/Away"]).sort_values('f',ascending=False).drop('f', axis=1).head(30)
# Out:
#        first_name            second_name   id  minutes    xG    xA   xGC  \
# 22           John                 Stones  302      368  0.18  0.08  1.41
# 109          John                 Stones  302      368  0.18  0.08  1.41
# 41        Emerson  Leite de Souza Junior  445      437  0.55  0.31  4.98
# 102         Trent       Alexander-Arnold  285      450  0.07  2.46  7.31
# 103         Trent       Alexander-Arnold  285      450  0.07  2.46  7.31
# 118         Diogo         Dalot Teixeira  342      450  0.80  0.30  9.77
# 0          Tyrone                  Mings   39      450  0.09  0.09  4.12
# 4       Alexandre          Moreno Lopera  694      405  0.18  1.16  3.56
# 64       Benjamin                  White   10      450  0.80  0.54  9.97
# 107  Konstantinos               Tsimikas  292      308  0.45  0.68  5.67
# 106  Konstantinos               Tsimikas  292      308  0.45  0.68  5.67
# 105        Joseph                  Gomez  286      450  0.06  0.50  8.13
# ...
